# %%
import pandas as pd

# %%
df = pd.read_csv('dataekp_0.csv')
print('Строк в датасете:', df.shape[0])
# Out:
# Строк в датасете: 76601

# %%
df.head(10)
# Out:
#                section       subsection                      title  \
# 0  Авиамодельный спорт  Основной состав               Кубок россии
# 1  Авиамодельный спорт  Основной состав               Кубок россии
# 2  Авиамодельный спорт  Основной состав               Кубок россии
# 3  Авиамодельный спорт  Основной состав               Кубок россии
# 4  Авиамодельный спорт  Основной состав               Кубок россии
# 5  Авиамодельный спорт  Основной состав               Кубок россии
# 6  Авиамодельный спорт  Основной состав               Кубок россии
# 7  Авиамодельный спорт  Основной состав  Учебно-тренировочный сбор
# 8  Авиамодельный спорт  Основной состав               Кубок россии
# 9  Авиамодельный спорт  Основной состав               Кубок россии
#
#                                     description       start        stop  \
# 0     кордовые модели воздушного боя F-2D  этап  2008-01-18  2008-01-20
# 1     кордовые модели воздушного боя F-2D  этап  2008-02-08  2008-02-10
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76601 entries, 0 to 76600
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   section       76601 non-null  object
#  1   subsection    76601 non-null  object
#  2   title         76601 non-null  object
#  3   description   65891 non-null  object
#  4   start         76601 non-null  object
#  5   stop          76601 non-null  object
#  6   address       76601 non-null  object
#  7   participants  76576 non-null  float64
# dtypes: float64(1), object(7)
# memory usage: 4.7+ MB
